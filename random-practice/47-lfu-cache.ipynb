# %%
Problem: LFU Cache
Difficulty: Hard
Link: https://leetcode.com/problems/lfu-cache/

Example:
LFUCache(2), put(1,1), put(2,2), get(1) -> 1, put(3,3), get(2) -> -1

Constraints:
- 0 <= capacity <= 10^4
- Up to 2 * 10^5 get/put calls

# %%
class LFUCache:
    def __init__(self, capacity: int):
        pass

    def get(self, key: int) -> int:
        pass

    def put(self, key: int, value: int) -> None:
        pass

# %%
def test(solution):
    cases = [
        ((2, ["put", "put", "get", "put", "get", "get", "put", "get", "get", "get"],
          [[1, 1], [2, 2], [1], [3, 3], [2], [3], [4, 4], [1], [3], [4]]),
         [None, None, 1, None, -1, 3, None, -1, 3, 4]),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(capacity, ops, params):
    cache = LFUCache(capacity)
    out = []
    for op, arg in zip(ops, params):
        if op == "put":
            out.append(cache.put(*arg))
        else:
            out.append(cache.get(*arg))
    return out

result = "PASS (No solution provided to execute)"
print(result)
# When LFUCache is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
