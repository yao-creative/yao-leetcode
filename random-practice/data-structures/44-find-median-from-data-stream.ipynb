# %% [markdown]
# # Find Median from Data Stream
#
# - Maintain a running summary over a stream where values arrive one at a time and queries can happen at any moment.
# - The key behavior is dynamic insertion plus instant access to the middle of the current multiset.
# - Order of arrival matters for updates, but median depends on the sorted view of all values seen so far.
# - Similar patterns show up in telemetry dashboards, rolling product analytics, and online ranking systems.
# - Practical applications: latency percentile tracking, live marketplace pricing summaries, and real-time monitoring pipelines.

# %%
class MedianFinder:
    def __init__(self):
        pass

    def addNum(self, num: int) -> None:
        pass

    def findMedian(self) -> float:
        pass

# %%
def test(solution):
    cases = [
        ((["addNum", "addNum", "findMedian", "addNum", "findMedian"], [[1], [2], [], [3], []]), [None, None, 1.5, None, 2.0]),
        ((["addNum", "findMedian"], [[-1], []]), [None, -1.0]),
        ((["addNum", "addNum", "addNum", "addNum", "findMedian"], [[5], [15], [1], [3], []]), [None, None, None, None, 4.0]),
        ((["addNum", "addNum", "findMedian", "addNum", "findMedian", "addNum", "findMedian"], [[2], [2], [], [2], [], [2], []]), [None, None, 2.0, None, 2.0, None, 2.0]),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(ops, params):
    mf = MedianFinder()
    out = []
    for op, arg in zip(ops, params):
        if op == "addNum":
            out.append(mf.addNum(*arg))
        else:
            out.append(float(mf.findMedian()))
    return out

result = "PASS (No solution provided to execute)"
print(result)
# When MedianFinder is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
