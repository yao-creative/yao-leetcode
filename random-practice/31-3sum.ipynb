# %%
Problem: 3Sum
Difficulty: Medium
Link: https://leetcode.com/problems/3sum/

Example 1:
Input: nums = [-1,0,1,2,-1,-4]
Output: [[-1,-1,2],[-1,0,1]]

Constraints:
- 3 <= nums.length <= 3000
- -10^5 <= nums[i] <= 10^5

# %%
class Solution:
    def threeSum(self, nums: list[int]) -> list[list[int]]:
        pass

# %%
def test(solution):
    cases = [
        (([-1, 0, 1, 2, -1, -4],), [[-1, -1, 2], [-1, 0, 1]]),
        (([0, 1, 1],), []),
        (([0, 0, 0],), [[0, 0, 0]]),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = sorted(sorted(x) for x in solution(*args))
        exp = sorted(sorted(x) for x in expected)
        assert got == exp, f'case {i}: expected {exp}, got {got}'

# %%
def current_solution(nums):
    return Solution().threeSum(nums)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().threeSum is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
