# %%
Problem: Merge k Sorted Lists
Difficulty: Hard
Link: https://leetcode.com/problems/merge-k-sorted-lists/

Example 1:
Input: lists = [[1,4,5],[1,3,4],[2,6]]
Output: [1,1,2,3,4,4,5,6]

Constraints:
- k == lists.length
- 0 <= k <= 10^4

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next


class Solution:
    def mergeKLists(self, lists: list[ListNode | None]) -> ListNode | None:
        pass

# %%
def test(solution):
    def build(values):
        dummy = ListNode()
        cur = dummy
        for v in values:
            cur.next = ListNode(v)
            cur = cur.next
        return dummy.next

    def dump(node):
        out = []
        while node:
            out.append(node.val)
            node = node.next
        return out

    cases = [
        (([[1, 4, 5], [1, 3, 4], [2, 6]],), [1, 1, 2, 3, 4, 4, 5, 6]),
        (([],), []),
        (([[]],), []),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        lists = [build(x) for x in args[0]]
        got = dump(solution(lists))
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(serialized_lists):
    def build(values):
        dummy = ListNode()
        cur = dummy
        for v in values:
            cur.next = ListNode(v)
            cur = cur.next
        return dummy.next

    lists = [build(x) for x in serialized_lists]
    return Solution().mergeKLists(lists)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().mergeKLists is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
