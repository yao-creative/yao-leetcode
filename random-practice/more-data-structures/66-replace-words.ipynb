# %%
Problem: Replace Words
Difficulty: Medium
Link: https://leetcode.com/problems/replace-words/

Example:
dictionary=["cat","bat","rat"], sentence="the cattle was rattled by the battery" -> "the cat was rat by the bat"

Constraints:
- 1 <= dictionary.length <= 1000
- Sentence contains lowercase letters and spaces

# %%
class Solution:
    def replaceWords(self, dictionary, sentence):
        pass

# %%
def test(solution):
    cases = [
        (((["cat", "bat", "rat"], "the cattle was rattled by the battery"), "the cat was rat by the bat")),
        (((["a", "b", "c"], "aadsfasf absbs bbab cadsfafs"), "a a b c")),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(dictionary, sentence):
    return Solution().replaceWords(dictionary, sentence)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution.replaceWords is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
