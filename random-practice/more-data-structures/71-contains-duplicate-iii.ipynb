# %%
Problem: Contains Duplicate III
Difficulty: Hard
Link: https://leetcode.com/problems/contains-duplicate-iii/

Example:
Input: nums = [1,2,3,1], indexDiff = 3, valueDiff = 0 -> Output: true

Constraints:
- 2 <= nums.length <= 10^5
- -10^9 <= nums[i] <= 10^9
- 1 <= indexDiff <= nums.length
- 0 <= valueDiff <= 10^9

# %%
from typing import List

class Solution:
    def containsNearbyAlmostDuplicate(self, nums: List[int], indexDiff: int, valueDiff: int) -> bool:
        pass

# %%
def test(solution):
    cases = [
        (([1, 2, 3, 1], 3, 0), True),
        (([1, 5, 9, 1, 5, 9], 2, 3), False),
        (([1, 0, 1, 1], 1, 2), True),
        (([8, 7, 15, 1, 6, 1, 9, 15], 1, 3), True),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(nums, indexDiff, valueDiff):
    return Solution().containsNearbyAlmostDuplicate(nums, indexDiff, valueDiff)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution.containsNearbyAlmostDuplicate is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
