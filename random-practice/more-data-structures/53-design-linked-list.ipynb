# %%
Problem: Design Linked List
Difficulty: Medium
Link: https://leetcode.com/problems/design-linked-list/

Example:
MyLinkedList(), addAtHead(1), addAtTail(3), addAtIndex(1,2), get(1) -> 2, deleteAtIndex(1), get(1) -> 3

Constraints:
- 0 <= index, val <= 1000
- At most 2000 get/add/delete calls

# %%
class MyLinkedList:
    def __init__(self):
        pass

    def get(self, index: int) -> int:
        pass

    def addAtHead(self, val: int) -> None:
        pass

    def addAtTail(self, val: int) -> None:
        pass

    def addAtIndex(self, index: int, val: int) -> None:
        pass

    def deleteAtIndex(self, index: int) -> None:
        pass

# %%
def test(solution):
    cases = [
        ((["addAtHead", "addAtTail", "addAtIndex", "get", "deleteAtIndex", "get"],
          [[1], [3], [1, 2], [1], [1], [1]]),
         [None, None, None, 2, None, 3]),
        ((["addAtHead", "deleteAtIndex", "addAtHead", "addAtTail", "get", "get"],
          [[7], [1], [2], [9], [0], [1]]),
         [None, None, None, None, 2, 9]),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(ops, params):
    obj = MyLinkedList()
    out = []
    for op, arg in zip(ops, params):
        out.append(getattr(obj, op)(*arg))
    return out

result = "PASS (No solution provided to execute)"
print(result)
# When MyLinkedList is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
