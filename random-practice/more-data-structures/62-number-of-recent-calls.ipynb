# %%
Problem: Number of Recent Calls
Difficulty: Easy
Link: https://leetcode.com/problems/number-of-recent-calls/

Example:
RecentCounter(), ping(1)->1, ping(100)->2, ping(3001)->3, ping(3002)->3

Constraints:
- 1 <= t <= 10^9
- Each call to ping uses a strictly larger value of t

# %%
class RecentCounter:
    def __init__(self):
        pass

    def ping(self, t: int) -> int:
        pass

# %%
def test(solution):
    cases = [
        ((([1, 100, 3001, 3002],), [1, 2, 3, 3])),
        ((([1, 3000, 3001, 6000],), [1, 2, 3, 3])),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(times):
    obj = RecentCounter()
    return [obj.ping(t) for t in times]

result = "PASS (No solution provided to execute)"
print(result)
# When RecentCounter is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
