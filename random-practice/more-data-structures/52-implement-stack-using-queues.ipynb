# %%
Problem: Implement Stack using Queues
Difficulty: Easy
Link: https://leetcode.com/problems/implement-stack-using-queues/

Example:
MyStack(), push(1), push(2), top() -> 2, pop() -> 2, empty() -> False

Constraints:
- 1 <= x <= 9
- At most 100 push/pop/top/empty calls

# %%
class MyStack:
    def __init__(self):
        pass

    def push(self, x: int) -> None:
        pass

    def pop(self) -> int:
        pass

    def top(self) -> int:
        pass

    def empty(self) -> bool:
        pass

# %%
def test(solution):
    cases = [
        ((["push", "push", "top", "pop", "empty"], [[1], [2], [], [], []]), [None, None, 2, 2, False]),
        ((["push", "top", "push", "pop", "top", "empty"], [[5], [], [7], [], [], []]), [None, 5, None, 7, 5, False]),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(ops, params):
    obj = MyStack()
    out = []
    for op, arg in zip(ops, params):
        out.append(getattr(obj, op)(*arg))
    return out

result = "PASS (No solution provided to execute)"
print(result)
# When MyStack is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
