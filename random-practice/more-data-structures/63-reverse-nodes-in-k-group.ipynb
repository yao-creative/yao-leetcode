# %%
Problem: Reverse Nodes in k-Group
Difficulty: Hard
Link: https://leetcode.com/problems/reverse-nodes-in-k-group/
Tags: NeetCode 150

Example:
Input: head=[1,2,3,4,5], k=2 -> [2,1,4,3,5]

Constraints:
- The number of nodes is in the range [1, 5000]
- 1 <= k <= n

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def reverseKGroup(self, head, k):
        pass

# %%
def build_list(values):
    dummy = ListNode()
    cur = dummy
    for value in values:
        cur.next = ListNode(value)
        cur = cur.next
    return dummy.next

def to_list(node):
    out = []
    while node:
        out.append(node.val)
        node = node.next
    return out

def test(solution):
    cases = [
        ((([1, 2, 3, 4, 5], 2), [2, 1, 4, 3, 5])),
        ((([1, 2, 3, 4, 5], 3), [3, 2, 1, 4, 5])),
        ((([1], 1), [1])),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        values, k = args
        got = solution(values, k)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(values, k):
    head = build_list(values)
    return to_list(Solution().reverseKGroup(head, k))

result = "PASS (No solution provided to execute)"
print(result)
# When Solution.reverseKGroup is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
