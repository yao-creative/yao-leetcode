# %%
Problem: Map Sum Pairs
Difficulty: Medium
Link: https://leetcode.com/problems/map-sum-pairs/

Example:
MapSum(), insert("apple",3), sum("ap")->3, insert("app",2), sum("ap")->5

Constraints:
- 1 <= key.length, prefix.length <= 50
- At most 50 calls

# %%
class MapSum:
    def __init__(self):
        pass

    def insert(self, key: str, val: int) -> None:
        pass

    def sum(self, prefix: str) -> int:
        pass

# %%
def test(solution):
    cases = [
        ((["insert", "sum", "insert", "sum"], [["apple", 3], ["ap"], ["app", 2], ["ap"]]), [None, 3, None, 5]),
        ((["insert", "sum", "insert", "sum"], [["apple", 3], ["ap"], ["apple", 2], ["ap"]]), [None, 3, None, 2]),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(ops, params):
    obj = MapSum()
    out = []
    for op, arg in zip(ops, params):
        out.append(getattr(obj, op)(*arg))
    return out

result = "PASS (No solution provided to execute)"
print(result)
# When MapSum is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
