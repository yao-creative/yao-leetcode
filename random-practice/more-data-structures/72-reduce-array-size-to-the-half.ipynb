# %%
Problem: Reduce Array Size to The Half
Difficulty: Medium
Link: https://leetcode.com/problems/reduce-array-size-to-the-half/

Example:
Input: arr = [3,3,3,3,5,5,5,2,2,7] -> Output: 2

Constraints:
- 2 <= arr.length <= 10^5
- arr.length is even
- 1 <= arr[i] <= 10^5

# %%
from typing import List

class Solution:
    def minSetSize(self, arr: List[int]) -> int:
        pass

# %%
def test(solution):
    cases = [
        (([3, 3, 3, 3, 5, 5, 5, 2, 2, 7],), 2),
        (([7, 7, 7, 7, 7, 7],), 1),
        (([1, 2, 3, 4],), 2),
        (([1, 1, 2, 2, 3, 3, 4, 4],), 2),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(arr):
    return Solution().minSetSize(arr)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution.minSetSize is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
