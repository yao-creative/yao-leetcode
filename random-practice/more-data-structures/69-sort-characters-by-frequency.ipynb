# %%
Problem: Sort Characters By Frequency
Difficulty: Medium
Link: https://leetcode.com/problems/sort-characters-by-frequency/

Example:
Input: s = "tree" -> Output can be "eert" or "eetr"

Constraints:
- 1 <= s.length <= 5 * 10^5
- s consists of uppercase/lowercase English letters and digits

# %%
class Solution:
    def frequencySort(self, s: str) -> str:
        pass

# %%
def test(solution):
    cases = [
        (("tree",), "eert"),
        (("cccaaa",), "aaaccc"),
        (("Aabb",), "bbAa"),
        (("z",), "z"),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(s):
    out = Solution().frequencySort(s)
    # Normalize ties by sorting groups of equal-frequency characters lexicographically.
    return ''.join(sorted(out, key=lambda c: (-out.count(c), c)))

result = "PASS (No solution provided to execute)"
print(result)
# When Solution.frequencySort is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
