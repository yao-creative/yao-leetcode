# %%
Problem: Insert Delete GetRandom O(1)
Difficulty: Medium
Link: https://leetcode.com/problems/insert-delete-getrandom-o1/

Example:
RandomizedSet(), insert(1) -> True, remove(2) -> False, insert(2) -> True, getRandom() -> 1 or 2, remove(1) -> True, insert(2) -> False

Constraints:
- About 2 * 10^5 operations
- Average O(1) required for insert/remove/getRandom

# %%
class RandomizedSet:
    def __init__(self):
        pass

    def insert(self, val: int) -> bool:
        pass

    def remove(self, val: int) -> bool:
        pass

    def getRandom(self) -> int:
        pass

# %%
def test(solution):
    cases = [
        ((["insert", "remove", "insert", "remove", "insert"], [[1], [2], [2], [1], [2]]), [True, False, True, True, False]),
        ((["insert", "insert", "remove", "insert", "remove"], [[10], [20], [10], [30], [40]]), [True, True, True, True, False]),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(ops, params):
    obj = RandomizedSet()
    out = []
    for op, arg in zip(ops, params):
        if op == "getRandom":
            value = getattr(obj, op)(*arg)
            out.append(value)
        else:
            out.append(getattr(obj, op)(*arg))
    return out

result = "PASS (No solution provided to execute)"
print(result)
# When RandomizedSet is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
