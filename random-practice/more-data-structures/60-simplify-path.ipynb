# %%
Problem: Simplify Path
Difficulty: Medium
Link: https://leetcode.com/problems/simplify-path/

Example:
Input: "/home//foo/" -> "/home/foo"

Constraints:
- 1 <= path.length <= 3000
- path consists of English letters, digits, period, slash, and underscore

# %%
class Solution:
    def simplifyPath(self, path):
        pass

# %%
def test(solution):
    cases = [
        ((("/home/",), "/home")),
        ((("/../",), "/")),
        ((("/home//foo/",), "/home/foo")),
        ((("/a/./b/../../c/",), "/c")),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(path):
    return Solution().simplifyPath(path)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution.simplifyPath is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
