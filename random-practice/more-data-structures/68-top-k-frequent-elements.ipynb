# %%
Problem: Top K Frequent Elements
Difficulty: Medium
Link: https://leetcode.com/problems/top-k-frequent-elements/

Example:
Input: nums = [1,1,1,2,2,3], k = 2 -> Output: [1,2] (order may vary)

Constraints:
- 1 <= nums.length <= 10^5
- k is in the range [1, number of unique elements]
- -10^4 <= nums[i] <= 10^4

# %%
from typing import List

class Solution:
    def topKFrequent(self, nums: List[int], k: int) -> List[int]:
        pass

# %%
def test(solution):
    cases = [
        (([1, 1, 1, 2, 2, 3], 2), [1, 2]),
        (([1], 1), [1]),
        (([4, 4, 4, 5, 5, 6], 2), [4, 5]),
        (([7, 8, 7, 9, 8, 8], 1), [8]),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(nums, k):
    # Normalize ordering because valid outputs may be in any order.
    return sorted(Solution().topKFrequent(nums, k))

result = "PASS (No solution provided to execute)"
print(result)
# When Solution.topKFrequent is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
