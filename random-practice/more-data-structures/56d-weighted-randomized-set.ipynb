# %% [markdown]
# ### Problem: Design Weighted Randomized Set
# **Difficulty:** Medium-Hard
# **Link:** Practice variant (next-step challenge from 380)
# **Tags:** Hash Map, Randomized Design, Weighted Sampling
#
# **Example:**
# `["WeightedSet","insertOrUpdate","insertOrUpdate","remove","insertOrUpdate"] / [[],[5,3],[8,7],[5],[8,7]] -> [null,true,true,true,false]`
#
# **Constraints:**
# - Implement mutation APIs first; weighted sampling API can be developed incrementally
# - `insertOrUpdate` returns True if value is new, else False when updating weight
# - `remove` returns True only if value existed

# %%
import random

class WeightedSet:
    def __init__(self):
        pass

    def insertOrUpdate(self, val: int, weight: int) -> bool:
        """If val is new, insert and return True; else update weight and return False."""
        pass

    def remove(self, val: int) -> bool:
        pass

    def getRandomWeighted(self) -> int:
        """Return val with probability proportional to its current weight."""
        pass

# %%
def test(solution):
    # Deterministic API checks (sampling distribution test is optional extension)
    ops = ["WeightedSet", "insertOrUpdate", "insertOrUpdate", "remove", "insertOrUpdate"]
    params = [[], [5, 3], [8, 7], [5], [8, 7]]

    got = solution(ops, params)
    expected = [None, True, True, True, False]
    assert got == expected, f"expected {expected}, got {got}"

# %%
def current_solution(ops, params):
    obj = None
    out = []
    for op, arg in zip(ops, params):
        if op == "WeightedSet":
            obj = WeightedSet(*arg)
            out.append(None)
            continue
        out.append(getattr(obj, op)(*arg))
    return out

# Uncomment after implementation:
# test(current_solution)
# print("PASS")
