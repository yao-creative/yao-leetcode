# %%
Problem: Online Stock Span
Difficulty: Medium
Link: https://leetcode.com/problems/online-stock-span/

Example:
StockSpanner(), next(100)->1, next(80)->1, next(60)->1, next(70)->2, next(60)->1, next(75)->4, next(85)->6

Constraints:
- 1 <= price <= 10^5
- At most 10^4 calls to next

# %%
class StockSpanner:
    def __init__(self):
        pass

    def next(self, price: int) -> int:
        pass

# %%
def test(solution):
    cases = [
        ((([100, 80, 60, 70, 60, 75, 85],), [1, 1, 1, 2, 1, 4, 6])),
        ((([31, 41, 48, 59, 79],), [1, 2, 3, 4, 5])),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(prices):
    obj = StockSpanner()
    return [obj.next(price) for price in prices]

result = "PASS (No solution provided to execute)"
print(result)
# When StockSpanner is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
