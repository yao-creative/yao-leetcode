# %%
Problem: Copy List with Random Pointer
Difficulty: Medium
Link: https://leetcode.com/problems/copy-list-with-random-pointer/

Example 1:
Input: head = [[7,null],[13,0],[11,4],[10,2],[1,0]]
Output: [[7,null],[13,0],[11,4],[10,2],[1,0]]

Constraints:
- 0 <= n <= 1000
- -10^4 <= Node.val <= 10^4

# %%
class Node:
    def __init__(self, x: int, next: 'Node' = None, random: 'Node' = None):
        self.val = x
        self.next = next
        self.random = random


class Solution:
    def copyRandomList(self, head: 'Node | None') -> 'Node | None':
        pass

# %%
def test(solution):
    def build(data):
        if not data:
            return None
        nodes = [Node(v) for v, _ in data]
        for i in range(len(nodes) - 1):
            nodes[i].next = nodes[i + 1]
        for i, (_, r) in enumerate(data):
            nodes[i].random = None if r is None else nodes[r]
        return nodes[0]

    def dump(head):
        if not head:
            return []
        arr, idx, cur = [], {}, head
        i = 0
        while cur:
            idx[id(cur)] = i
            arr.append(cur)
            cur = cur.next
            i += 1
        out = []
        for node in arr:
            out.append([node.val, None if node.random is None else idx[id(node.random)]])
        return out

    cases = [
        (([[7, None], [13, 0], [11, 4], [10, 2], [1, 0]],), [[7, None], [13, 0], [11, 4], [10, 2], [1, 0]]),
        (([],), []),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        head = build(args[0])
        got = dump(solution(head))
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(serialized_head):
    def build(data):
        if not data:
            return None
        nodes = [Node(v) for v, _ in data]
        for i in range(len(nodes) - 1):
            nodes[i].next = nodes[i + 1]
        for i, (_, r) in enumerate(data):
            nodes[i].random = None if r is None else nodes[r]
        return nodes[0]

    return Solution().copyRandomList(build(serialized_head))

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().copyRandomList is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
