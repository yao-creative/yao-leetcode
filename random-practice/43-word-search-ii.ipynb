# %%
Problem: Word Search II
Difficulty: Hard
Link: https://leetcode.com/problems/word-search-ii/

Example 1:
Input: board = [["o","a","a","n"],["e","t","a","e"],["i","h","k","r"],["i","f","l","v"]], words = ["oath","pea","eat","rain"]
Output: ["eat","oath"]

Constraints:
- 1 <= m, n <= 12
- 1 <= words.length <= 3 * 10^4

# %%
class Solution:
    def findWords(self, board: list[list[str]], words: list[str]) -> list[str]:
        pass

# %%
def test(solution):
    cases = [
        ((([["o", "a", "a", "n"], ["e", "t", "a", "e"], ["i", "h", "k", "r"], ["i", "f", "l", "v"]], ["oath", "pea", "eat", "rain"]),), ["eat", "oath"]),
        ((([["a", "b"], ["c", "d"]], ["abcb"]),), []),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        board, words = args[0]
        got = sorted(solution(board, words))
        exp = sorted(expected)
        assert got == exp, f'case {i}: expected {exp}, got {got}'

# %%
def current_solution(board_and_words):
    board, words = board_and_words
    return Solution().findWords(board, words)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().findWords is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
