# %%
Problem: Binary Tree Maximum Path Sum
Difficulty: Hard
Link: https://leetcode.com/problems/binary-tree-maximum-path-sum/

Example 1:
Input: root = [1,2,3]
Output: 6

Constraints:
- Number of nodes is in [1, 3 * 10^4]
- -1000 <= Node.val <= 1000

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right


class Solution:
    def maxPathSum(self, root: TreeNode | None) -> int:
        pass

# %%
def test(solution):
    def build(level):
        if not level:
            return None
        nodes = [None if v is None else TreeNode(v) for v in level]
        kids = nodes[::-1]
        root = kids.pop()
        for node in nodes:
            if node:
                if kids:
                    node.left = kids.pop()
                if kids:
                    node.right = kids.pop()
        return root

    cases = [
        (([1, 2, 3],), 6),
        (([-10, 9, 20, None, None, 15, 7],), 42),
        (([2, -1],), 2),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(build(args[0]))
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(level_order):
    def build(level):
        if not level:
            return None
        nodes = [None if v is None else TreeNode(v) for v in level]
        kids = nodes[::-1]
        root = kids.pop()
        for node in nodes:
            if node:
                if kids:
                    node.left = kids.pop()
                if kids:
                    node.right = kids.pop()
        return root

    return Solution().maxPathSum(build(level_order))

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().maxPathSum is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
