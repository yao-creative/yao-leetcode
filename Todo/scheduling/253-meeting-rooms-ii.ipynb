# %% [markdown]
# # Meeting Rooms II
#
# - Difficulty: Medium.
# - Scheduling problem about the minimum number of concurrent resources needed.
# - Watch overlap counting, reuse of freed rooms, and same-time start/end boundaries.
# - Similar logic appears in capacity planning, worker allocation, and rate-limited job dispatch.

# %%
def test(solution):
    cases = [
        (([[0, 30], [5, 10], [15, 20]],), 2),
        (([[7, 10], [2, 4]],), 1),
        (([],), 0),
        (([[1, 5], [5, 8], [8, 10]],), 1),
        (([[1, 4], [2, 3], [3, 6]],), 2),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(intervals):
    return Solution().minMeetingRooms(intervals)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().minMeetingRooms is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
