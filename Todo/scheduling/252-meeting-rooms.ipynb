# %% [markdown]
# # Meeting Rooms
#
# - Difficulty: Easy.
# - Scheduling problem about whether a set of intervals can coexist without overlap.
# - Focus on interval boundaries, sorted order, and what counts as a conflict.
# - Similar checks appear in calendar validation, resource booking, and deployment windows.

# %%
def test(solution):
    cases = [
        (([[0, 30], [5, 10], [15, 20]],), False),
        (([[7, 10], [2, 4]],), True),
        (([],), True),
        (([[1, 5], [5, 8]],), True),
        (([[1, 4], [2, 3]],), False),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(intervals):
    return Solution().canAttendMeetings(intervals)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().canAttendMeetings is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
