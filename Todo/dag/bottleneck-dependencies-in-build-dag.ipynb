# %% [markdown]
# # Bottleneck Dependencies in Build DAG
#
# - DAG scheduling problem based on build prerequisites and parallel-ready batches.
# - Focus on which nodes become ready together at each build step, not just on final topological order.
# - Important behaviors: readiness waves, isolated build steps, and how parallelism changes after prerequisites are removed.
# - Practical applications: build pipelines, workflow orchestration, task unlock analysis, and dependency bottleneck detection.

# %%
def test(solution):
    cases = [
        (((5, [[0, 1], [0, 2], [1, 3], [1, 4]])), [0]),
        (((1, [])), [0]),
        (((3, [[0, 1], [1, 2]])), [0, 1, 2]),
        (((4, [[0, 2], [1, 2], [2, 3]])), [2, 3]),
        (((4, [[0, 1], [0, 2], [1, 3], [2, 3]])), [0, 3]),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(n, edges):
    return Solution().findBottleneckDependencies(n, edges)

result = 'PASS (No solution provided to execute)'
print(result)
# When Solution().findBottleneckDependencies is runnable, replace the two lines above with:
# test(current_solution)
# print('PASS')
