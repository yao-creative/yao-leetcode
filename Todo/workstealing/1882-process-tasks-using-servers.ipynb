# %% [markdown]
# # 1882. Process Tasks Using Servers
#
# - ROI: High as a work-stealing proxy, even though LeetCode does not model true deque-based work stealing directly.
# - Focus: routing waiting work to the next available worker, balancing utilization, and modeling idle vs busy pools under time.
# - Why this folder: closest practical scheduler question here for reasoning about worker assignment pressure before moving on to real ForkJoin/work-stealing runtimes.
# - AI systems mapping: inference worker assignment, agent job dispatch, and heterogeneous server pools with queue pressure.

# %%
def test(solution):
    cases = [
        ((([3, 3, 2], [1, 2, 3, 2, 1, 2])), [2, 2, 0, 2, 1, 2]),
        ((([5, 1, 4, 3, 2], [2, 1, 2, 4, 5, 2, 1])), [1, 4, 1, 4, 1, 3, 2]),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(servers, tasks):
    return Solution().assignTasks(servers, tasks)

result = 'PASS (No solution provided to execute)'
print(result)
# When Solution().assignTasks is runnable, replace the two lines above with:
# test(current_solution)
# print('PASS')
