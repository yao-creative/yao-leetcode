# %% [markdown]
# # 1500. Design a File Sharing System
#
# Practical applications:
# - Peer-to-peer file distribution where peers advertise available pieces and can disconnect and reconnect.
# - Download managers or sync systems that track which clients already hold specific shards.
# - Backend resource-allocation services that must recycle small integer IDs without collisions.
# - Product features that combine membership changes with immediate access propagation.
#
# Reference example:
# - `ops = ["FileSharing", "join", "join", "join", "request", "request", "leave", "request", "leave", "join"]`
# - `args = [[4], [1, 2], [2, 3], [4], [1, 3], [2, 2], [1], [2, 1], [2], []]`
# - `expected = [None, 1, 2, 3, [2], [1, 2], None, [], None, 1]`

# %%
def test(solution):
    cases = [
        (((
            ["FileSharing", "join", "join", "join", "request", "request", "leave", "request", "leave", "join"],
            [[4], [1, 2], [2, 3], [4], [1, 3], [2, 2], [1], [2, 1], [2], []],
        )),
         [None, 1, 2, 3, [2], [1, 2], None, [], None, 1]),
        (((
            ["FileSharing", "join", "request", "leave", "join", "request"],
            [[5], [], [1, 1], [1], [2], [1, 2]],
        )),
         [None, 1, [], None, 1, [1]]),
        (((
            ["FileSharing", "join", "join", "request", "request"],
            [[3], [1], [3], [1, 2], [2, 2]],
        )),
         [None, 1, 2, [], []]),
    ]

    for i, (args, expected) in enumerate(cases):
        got = solution(*args)
        assert got == expected, f"case {i}: expected={expected}, got={got}"

# %%
def current_solution(ops, args):
    # Implement your operation runner, then return outputs list.
    # Typical structure:
    # out = []
    # obj = None
    # for op, a in zip(ops, args):
    #     if op == "FileSharing":
    #         obj = FileSharing(*a)
    #         out.append(None)
    #     elif op == "join":
    #         out.append(obj.join(a))
    #     elif op == "leave":
    #         out.append(obj.leave(a[0]))
    #     elif op == "request":
    #         out.append(obj.request(a[0], a[1]))
    # return out
    raise NotImplementedError

result = 'PASS (No solution provided to execute)'
print(result)
# When current_solution is runnable, replace the two lines above with:
# test(current_solution)
# print('PASS')
