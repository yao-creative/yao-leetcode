# %% [markdown]
# # Path With Maximum Probability
#
# - Difficulty: Medium.
# - Best-first path search where the score compounds across edges instead of adding normally.
# - Keep track of how partial candidates are ranked as the frontier grows.
# - Similar patterns show up in recommendation walks, reliability routing, and ranking pipelines.
# - Important cases: disconnected graphs, revisits with better scores, and precision handling.

# %%
def test(solution):
    cases = [
        ((3, [[0, 1], [1, 2], [0, 2]], [0.5, 0.5, 0.2], 0, 2), 0.25),
        ((3, [[0, 1], [1, 2], [0, 2]], [0.5, 0.5, 0.3], 0, 2), 0.3),
        ((3, [[0, 1]], [0.5], 0, 2), 0.0),
        ((5, [[0, 1], [1, 2], [0, 2], [2, 3], [3, 4]], [0.9, 0.9, 0.5, 0.8, 0.9], 0, 4), 0.5832),
        ((1, [], [], 0, 0), 1.0),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(n, edges, succProb, start_node, end_node):
    return round(Solution().maxProbability(n, edges, succProb, start_node, end_node), 10)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().maxProbability is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
