# %% [markdown]
# # Cheapest Flights Within K Stops
#
# - Difficulty: Medium.
# - Frontier-search problem over travel states with both cost and stop-count constraints.
# - Focus on what information must stay attached to each partial route.
# - Similar tradeoffs appear in routing systems, itinerary ranking, and constrained planning.
# - Important behaviors: stop limits, unreachable destinations, and cheaper later expansions.

# %%
def test(solution):
    cases = [
        ((4, [[0, 1, 100], [1, 2, 100], [2, 0, 100], [1, 3, 600], [2, 3, 200]], 0, 3, 1), 700),
        ((3, [[0, 1, 100], [1, 2, 100], [0, 2, 500]], 0, 2, 1), 200),
        ((3, [[0, 1, 100], [1, 2, 100], [0, 2, 500]], 0, 2, 0), 500),
        ((5, [[0, 1, 5], [1, 2, 5], [0, 3, 2], [3, 1, 2], [1, 4, 1], [4, 2, 1]], 0, 2, 2), 7),
        ((3, [[0, 1, 100], [1, 0, 100]], 0, 2, 1), -1),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(n, flights, src, dst, k):
    return Solution().findCheapestPrice(n, flights, src, dst, k)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().findCheapestPrice is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
