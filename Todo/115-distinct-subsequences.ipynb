# %% [markdown]
# # Distinct Subsequences
#
# - Counting problem over ordered character choices rather than contiguous windows.
# - Pay attention to skip-vs-use decisions and the meaning of an empty target.
# - Similar patterns appear in event stream matching and rule-counting systems.
# - The difficulty is avoiding double counting while preserving order.

# %%
def test(solution):
    cases = [
        (("rabbbit", "rabbit"), 3),
        (("babgbag", "bag"), 5),
        (("abc", "abcd"), 0),
        (("", ""), 1),
        (("aaaaa", "aa"), 10),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(s, t):
    return Solution().numDistinct(s, t)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().numDistinct is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
