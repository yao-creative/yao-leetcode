# %% [markdown]
# # Maximum Subarray with Required Minimum Length `k`
#
# Return the maximum subarray sum among all contiguous subarrays whose length is at least `k`.
#
# Learning goal intent:
# - learn when plain Kadane is no longer sufficient and when prefix sums or hybrid state are needed
#
# What changed from the original problem:
# - a hard structural constraint is added to valid subarrays
#
# Why this change matters for design decisions:
# - local extend-vs-restart alone no longer captures feasibility

# %%
def test(solution):
    cases = [
        (([1, 2, 3], 2), 6),
        (([-1, -2, -3], 2), -3),
        (([1, -2, 3, 4], 2), 7),
        (([5, -10, 4, 3, 2], 3), 9),
        (([2, -1, 2], 2), 3),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(nums, k):
    return Solution().maxSubArrayAtLeastK(nums, k)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().maxSubArrayAtLeastK is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
# Out:
# PASS (No solution provided to execute)
