# %% [markdown]
# # One Edit Distance
#
# - Small string comparison problem centered on exactly one modification.
# - Key behaviors: equal strings, single insert/delete/replace, and length gaps beyond one.
# - Useful for input validation, typo tolerance, and near-duplicate filtering.
# - The challenge is being precise about exactness, not just closeness.

# %%
class Solution:
    def isOneEditDistance(self, s, t):
        # O (N) algorithm
        i = 0
        j = 0 


        # we can use a hashmap, but then that's not unique, however i realized that it's 
        # just one edit distance not one letter distance, so it requires fixed permutation, this is way easier

        # 3 cases for accept one word has a prefix on the other of 1.
        # one word has suffix on the other of 1
        # one of the letters is missing in the middle 
        one_diff = False 
        while i < len(s) and j < len(t):
            if s[i] != t[j]:
                one_diff = True
            elif one_diff:

# %%
def test(solution):
    cases = [
        (("ab", "acb"), True),
        (("", ""), False),
        (("a", ""), True),
        (("cab", "ad"), False),
        (("1203", "1213"), True),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(s, t):
    return Solution().isOneEditDistance(s, t)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().isOneEditDistance is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
