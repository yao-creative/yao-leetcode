# %% [markdown]
# # Edit Distance
#
# - String transformation problem with local operations and a global minimum.
# - Focus on how prefixes or suffixes relate after one small edit.
# - Important behaviors: empty-string edges, matching characters, and unequal lengths.
# - Shows up in fuzzy search, typo correction, and record deduplication pipelines.

# %%
def test(solution):
    cases = [
        (("horse", "ros"), 3),
        (("intention", "execution"), 5),
        (("", "abc"), 3),
        (("abc", "abc"), 0),
        (("kitten", "sitting"), 3),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(word1, word2):
    return Solution().minDistance(word1, word2)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().minDistance is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
