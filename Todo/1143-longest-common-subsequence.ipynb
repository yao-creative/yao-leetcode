# %% [markdown]
# # Longest Common Subsequence
#
# - Sequence alignment problem focused on longest ordered overlap.
# - Important behaviors: matching choices, skips on either side, and empty-input edges.
# - This pattern appears in diffing, change review tools, and sequence comparison tasks.
# - The key is preserving order while maximizing retained information.

# %%
def test(solution):
    cases = [
        (("abcde", "ace"), 3),
        (("abc", "abc"), 3),
        (("abc", "def"), 0),
        (("", "abc"), 0),
        (("bsbininm", "jmjkbkjkv"), 1),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(text1, text2):
    return Solution().longestCommonSubsequence(text1, text2)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().longestCommonSubsequence is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
