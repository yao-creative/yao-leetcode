# %% [markdown]
# # Redundant Connection
#
# - Incremental graph validity check where one extra edge breaks the tree property.
# - The key behavior is detecting the last edge that introduces a cycle under the problem rules.
# - Similar patterns appear in dependency validation, network topology checks, and config drift repair.
# - Think about connectivity invariants as edges arrive one by one.

# %%
def test(solution):
    cases = [
        ((([[1, 2], [1, 3], [2, 3]],)), [2, 3]),
        ((([[1, 2], [2, 3], [3, 4], [1, 4], [1, 5]],)), [1, 4]),
        ((([[1, 2], [2, 3], [3, 1]],)), [3, 1]),
        ((([[1, 2], [2, 3], [3, 4], [4, 1], [1, 5], [5, 6]],)), [4, 1]),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(edges):
    return Solution().findRedundantConnection(edges)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().findRedundantConnection is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
