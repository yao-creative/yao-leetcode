# %% [markdown]
# # 3530. Maximum Profit from Valid Topological Order in DAG
#
# You are given a DAG with `n` nodes, directed edges `u -> v`, and a score on each node. Process the nodes in any valid topological order, assigning 1-based positions, and maximize the total profit `sum(score[node] * position)`.
#
# Reference examples:
# - `n = 2, edges = [[0, 1]], score = [2, 3]` -> `8`
# - `n = 3, edges = [[0, 1], [0, 2]], score = [1, 6, 3]` -> `25`
#
# Constraints worth noticing:
# - `1 <= n <= 22`, which strongly suggests bitmask DP is viable.
# - The graph is guaranteed to be a DAG.
# - `0 <= edges.length <= n * (n - 1) / 2`.

# %%
def test(solution):
    cases = [
        ((2, [[0, 1]], [2, 3]), 8),
        ((3, [[0, 1], [0, 2]], [1, 6, 3]), 25),
        ((3, [], [1, 2, 3]), 14),
        ((4, [[0, 2], [1, 2], [1, 3]], [5, 1, 4, 3]), 31),
    ]

    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f"case {i}: expected={expected}, got={got}"

# %%
def current_solution(n, edges, score):
    return Solution().maxProfit(n, edges, score)

result = 'PASS (No solution provided to execute)'
print(result)
# When Solution().maxProfit is runnable, replace the two lines above with:
# test(current_solution)
# print('PASS')
