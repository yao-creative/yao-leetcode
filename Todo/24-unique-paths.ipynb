# %%
Input: m = 3, n = 6

Output: 21
Example 2:

Input: m = 3, n = 3

Output: 6
Constraints:

1 <= m, n <= 100

# %%
class Solution:
    def uniquePaths(self, m: int, n: int) -> int:

# %%
def test(solution):
    cases = [
        ((3, 7), 28),
        ((3, 2), 3),
        ((3, 3), 6),
        ((1, 1), 1),
        ((1, 10), 1),
        ((10, 1), 1),
        ((3, 6), 21),
        ((10, 10), 48620),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(m, n):
    return Solution().uniquePaths(m, n)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().uniquePaths is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
