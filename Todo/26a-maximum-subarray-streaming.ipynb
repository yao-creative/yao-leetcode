# %% [markdown]
# # Maximum Subarray in a Streaming Interface
#
# Numbers arrive one at a time. After each new number, report the best maximum-subarray sum seen so far over the stream prefix.
#
# Learning goal intent:
# - strengthen the rolling-state invariant until it feels natural without relying on array indexing
#
# What changed from the original problem:
# - the interface is online instead of batch
#
# Why this change matters for design decisions:
# - it removes any temptation to use full-array DP storage and forces state minimality
#
# Suggested output contract for this draft notebook:
# - input: `nums: List[int]`
# - output: `List[int]` where output[i] is the best maximum-subarray sum after processing `nums[:i+1]`

# %%
def test(solution):
    cases = [
        (([-2, 1, -3, 4, -1, 2, 1, -5, 4],), [-2, 1, 1, 4, 4, 5, 6, 6, 6]),
        (([1],), [1]),
        (([-1, -2, -3],), [-1, -1, -1]),
        (([5, -2, 3],), [5, 5, 6]),
        (([0, 0, 0],), [0, 0, 0]),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(nums):
    return Solution().maxSubArrayStream(nums)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().maxSubArrayStream is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
# Out:
# PASS (No solution provided to execute)
