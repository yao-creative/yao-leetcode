# %% [markdown]
# # Regular Expression Matching
#
# - Full-string pattern matching with controlled repetition semantics.
# - Focus on how current characters interact with optional repeated groups.
# - Real-world analogs include validation engines, parsing gates, and rule evaluators.
# - Small local choices can unlock or block the rest of the pattern.

# %%
def test(solution):
    cases = [
        (("aa", "a"), False),
        (("aa", "a*"), True),
        (("ab", ".*"), True),
        (("aab", "c*a*b"), True),
        (("mississippi", "mis*is*p*."), False),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(s, p):
    return Solution().isMatch(s, p)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().isMatch is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
