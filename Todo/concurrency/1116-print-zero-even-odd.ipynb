# %% [markdown]
# # 1116. Print Zero Even Odd
#
# - ROI: High. Good for mastering turn-taking protocols, condition handoff, and state machines across threads.
# - Focus: ownership of the next state, avoiding missed notifications, and proving no thread can print out of order.
# - AI systems mapping: staged pipelines where one coordinator thread feeds specialized workers in a strict sequence.

# %%
def test(solution_cls):
    out = []
    z = solution_cls(5)
    z.zero(lambda x: out.append(str(x)))
    z.odd(lambda x: out.append(str(x)))
    z.even(lambda x: out.append(str(x)))
    assert set(''.join(out)) <= set('012345')
    # Full validation needs real multithreaded execution.

# %%
def current_solution(n):
    return ZeroEvenOdd(n)

result = 'PASS (No solution provided to execute)'
print(result)
# When ZeroEvenOdd is runnable with a threaded harness, replace the two lines above with:
# test(current_solution)
# print('PASS')
