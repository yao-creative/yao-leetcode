# %% [markdown]
# # 1494. Parallel Courses II
#
# - Hard scheduling problem on a prerequisite DAG with a per-semester throughput cap.
# - Focus on dependency readiness, semester batching, and proving that a locally appealing pick does not always minimize total semesters.
# - Similar patterns show up in workflow orchestration, build systems, and agent plans with both dependencies and limited parallel slots.
# - Practical applications: job schedulers, staged deployments, bounded worker pools, and planning under concurrency limits.

# %%
def test(solution):
    cases = [
        (((4, [[2, 1], [3, 1], [1, 4]], 2)), 3),
        (((5, [[2, 1], [3, 1], [4, 1], [1, 5]], 2)), 4),
        (((3, [], 2)), 2),
        (((1, [], 1)), 1),
        (((4, [[1, 4], [2, 4], [3, 4]], 3)), 2),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(n, relations, k):
    return Solution().minNumberOfSemesters(n, relations, k)

result = 'PASS (No solution provided to execute)'
print(result)
# When Solution().minNumberOfSemesters is runnable, replace the two lines above with:
# test(current_solution)
# print('PASS')
