# %% [markdown]
# # Largest Rectangle in Histogram, Huge-Height Constraint Variant
#
# Solve the histogram problem again, but heights may be as large as `10^12`, so any representation proportional to height values is invalid.
#
# - This variant is about state compression under stricter constraints.
# - Value magnitude must not affect memory usage.
# - The core challenge is choosing a representation proportional only to the number of bars.
# - Boundary reasoning is still the main correctness lever.
# - Similar patterns show up in large-scale metrics processing where values are huge but the sequence length is manageable.
#
# Suggested output contract for this draft notebook:
# - input: `heights: List[int]`
# - output: `int` largest rectangle area

# %%
def test(solution):
    cases = [
        (([2, 1, 5, 6, 2, 3],), 10),
        (([10**12],), 10**12),
        (([10**12, 10**12],), 2 * 10**12),
        (([10**12, 1, 10**12],), 10**12),
        (([3, 3, 3, 3, 3],), 15),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(heights):
    return Solution().largestRectangleArea(heights)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().largestRectangleArea is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
