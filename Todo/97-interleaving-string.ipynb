# %% [markdown]
# # Interleaving String
#
# - Merge-validation problem where relative order inside each input must stay intact.
# - Watch the length check, ambiguous branch points, and repeated characters.
# - Similar constraints appear in log reconstruction and merged event stream validation.
# - The main invariant is whether a prefix can be formed from two earlier prefixes.

# %%
def test(solution):
    cases = [
        (("aabcc", "dbbca", "aadbbcbcac"), True),
        (("aabcc", "dbbca", "aadbbbaccc"), False),
        (("", "", ""), True),
        (("", "abc", "abc"), True),
        (("abc", "def", "adbcef"), True),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(s1, s2, s3):
    return Solution().isInterleave(s1, s2, s3)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().isInterleave is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
