# %% [markdown]
# # 2050. Parallel Courses III
#
# - ROI: High for reasoning about async execution over DAGs, critical paths, and throughput under dependency constraints.
# - Focus: topological scheduling, earliest-start propagation, and identifying the true bottleneck path instead of counting only local work.
# - AI systems mapping: agent plans with tool dependencies, workflow compilers, batch execution planners, and parallel subtask orchestration.

# %%
def test(solution):
    cases = [
        (((3, [[1, 3], [2, 3]], [3, 2, 5])), 8),
        (((5, [[1, 5], [2, 5], [3, 5], [3, 4], [4, 5]], [1, 2, 3, 4, 5])), 12),
        (((2, [], [5, 7])), 7),
        (((4, [[1, 2], [2, 3], [3, 4]], [2, 2, 2, 2])), 8),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(n, relations, time):
    return Solution().minimumTime(n, relations, time)

result = 'PASS (No solution provided to execute)'
print(result)
# When Solution().minimumTime is runnable, replace the two lines above with:
# test(current_solution)
# print('PASS')
