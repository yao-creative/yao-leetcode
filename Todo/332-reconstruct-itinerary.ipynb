# %% [markdown]
# # Reconstruct Itinerary
#
# - Constraint-driven traversal where every ticket must be used exactly once.
# - The interesting behavior is building a valid route while respecting lexical tie-breaking.
# - Similar structures appear in job sequencing, route replay, and ordered audit reconstruction.
# - Track what must be consumed, what order is required, and when backtracking is needed.

# %%
def test(solution):
    cases = [
        ((([["MUC", "LHR"], ["JFK", "MUC"], ["SFO", "SJC"], ["LHR", "SFO"]],)), ["JFK", "MUC", "LHR", "SFO", "SJC"]),
        ((([["JFK", "SFO"], ["JFK", "ATL"], ["SFO", "ATL"], ["ATL", "JFK"], ["ATL", "SFO"]],)), ["JFK", "ATL", "JFK", "SFO", "ATL", "SFO"]),
        ((([["JFK", "KUL"], ["JFK", "NRT"], ["NRT", "JFK"]],)), ["JFK", "NRT", "JFK", "KUL"]),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(tickets):
    return Solution().findItinerary(tickets)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().findItinerary is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
