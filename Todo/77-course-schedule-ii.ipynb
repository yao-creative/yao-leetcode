# %% [markdown]
# # Course Schedule II
#
# - Graph ordering problem: produce one valid course order if dependencies allow it.
# - The output behavior matters as much as feasibility: every course should appear exactly once in a valid dependency-respecting order.
# - Important invariants are cycle detection, prerequisite direction, and validating all nodes are included.
# - Similar patterns appear in build pipelines, DAG task runners, release sequencing, and database migration planning.
# - Test both impossible cases and multiple-node graphs where several valid orders may exist.

# %%
class Solution:
    def findOrder(self, numCourses: int, prerequisites: list[list[int]]) -> list[int]:
        pass

# %%
def test(solution):
    cases = [
        (((2, [[1, 0]])), [0, 1]),
        (((4, [[1, 0], [2, 0], [3, 1], [3, 2]])), [0, 1, 2, 3]),
        (((1, [])), [0]),
        (((2, [[1, 0], [0, 1]])), []),
        (((4, [[1, 0], [2, 1], [3, 2]])), [0, 1, 2, 3]),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(numCourses, prerequisites):
    return Solution().findOrder(numCourses, prerequisites)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().findOrder is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
