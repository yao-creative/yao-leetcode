# %% [markdown]
# # Circular Maximum Subarray
#
# Return the maximum possible subarray sum in a circular array, where a valid subarray may wrap from the end back to the beginning.
#
# Learning goal intent:
# - understand how the same core idea can split into complementary cases
#
# What changed from the original problem:
# - contiguity may wrap from the end of the array back to the start
#
# Why this change matters for design decisions:
# - the best answer may be easier to compute through total sum minus minimum subarray rather than direct recurrence alone

# %%
def test(solution):
    cases = [
        (([1, -2, 3, -2],), 3),
        (([5, -3, 5],), 10),
        (([-3, -2, -3],), -2),
        (([3, -1, 2, -1],), 4),
        (([3, -2, 2, -3],), 3),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(nums):
    return Solution().maxSubarraySumCircular(nums)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().maxSubarraySumCircular is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
# Out:
# PASS (No solution provided to execute)
