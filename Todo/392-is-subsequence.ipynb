# %% [markdown]
# # Is Subsequence
#
# - Order-checking problem: characters can be skipped but not reordered.
# - Core behaviors are empty inputs, early mismatch, and advancing through a long source.
# - Common in filtering, permission matching, and lightweight stream validation.
# - This is a good exercise in maintaining a simple invariant across two sequences.

# %%
def test(solution):
    cases = [
        (("abc", "ahbgdc"), True),
        (("axc", "ahbgdc"), False),
        (("", "ahbgdc"), True),
        (("abc", "abc"), True),
        (("aaaaaa", "bbaaaa"), False),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(s, t):
    return Solution().isSubsequence(s, t)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().isSubsequence is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
