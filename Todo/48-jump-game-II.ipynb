# %%
def test(solution):
    cases = [
        (([2, 3, 1, 1, 4],), 2),
        (([2, 3, 0, 1, 4],), 2),
        (([0],), 0),
        (([1, 1],), 1),
        (([1, 2, 1, 1, 1],), 3),
        (([1, 2, 3],), 2),
        (([4, 1, 1, 3, 1, 1, 1],), 2),
    ]
    for i, (args, expected) in enumerate(cases, 1):
        got = solution(*args)
        assert got == expected, f'case {i}: expected {expected}, got {got}'

# %%
def current_solution(nums):
    return Solution().jump(nums)

result = "PASS (No solution provided to execute)"
print(result)
# When Solution().jump is runnable, replace the two lines above with:
# test(current_solution)
# print("PASS")
